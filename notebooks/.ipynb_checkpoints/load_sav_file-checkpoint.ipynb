# %%
from load import load_sav

df = load_sav("../data/brilliant_working.sav")

# %%
df
# Out:
#              id edition a1  a2_1  a2_2   a3 a3_des   a4 a4_des     a5  ...  \
# 0    11372211.0      乙版  女  77.0   7.0  閩南人    999  閩南人    999     高職  ...
# 1    11372212.0      乙版  男  76.0   9.0  閩南人    999  閩南人    999  國(初)中  ...
# 2    11372213.0      乙版  女  74.0   2.0  閩南人    999  閩南人    999  國(初)中  ...
# 3    11372509.0      甲版  男  83.0  10.0  閩南人    999  外省人    999  國(初)中  ...
# 4    11372517.0      甲版  女  48.0   9.0  客家人    999  閩南人    999   小學畢業  ...
# ..          ...     ... ..   ...   ...  ...    ...  ...    ...    ...  ...
# 863  23401723.0      乙版  女  49.0   1.0  閩南人    999  閩南人    999   小學肄業  ...
# 864  23401724.0      乙版  女  69.0  10.0  閩南人    999  閩南人    999   小學畢業  ...
# 865  23401830.0      乙版  女  39.0  10.0  閩南人    999  閩南人    999   小學畢業  ...
# 866  23401915.0      乙版  男  68.0   4.0  閩南人    999  閩南人    999  國(初)中  ...
# 867  23402017.0      甲版  男  42.0  12.0  閩南人    999  客家人    999   小學畢業  ...
#
# ...
