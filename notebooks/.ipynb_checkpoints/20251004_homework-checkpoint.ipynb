# %% [markdown]
# # 1141_社會資料分析 作業二
# 姓名：劉晏成

# %% [markdown]
# ## 題目
# 以「2018台北大學社會系三鶯調查」（brilliant_working.sav）檔案回答下列問題：
# 1. 計算環境行為（c1）總分的集中量數（平均數、中位數、眾數）和變異量數（全距、四分位差、標準差）
# 2. 分別計算個人收入（b1）的百分等級和Z分數，並比較原始分數、百分等級、Z分數三者的偏態

# %%
from load import load_sav

df = load_sav("../data/brilliant_working.sav")

# %%
variable_value_labels = df.attrs['variable_value_labels']
column_names = df.attrs['column_names']
column_names_to_labels = df.attrs['column_names_to_labels']

# %% [markdown]
# ## Q1: 計算環境行為（c1）總分的集中量數（平均數、中位數、眾數）和變異量數（全距、四分位差、標準差）

# %%
df_1 = df[['c1a', 'c1b', 'c1c', 'c1d', 'c1e', 'c1f', 'c1g']].copy()

# %%
df_1.loc[:, 'c1_sum'] = df_1[['c1a', 'c1b', 'c1c', 'c1d', 'c1e', 'c1f', 'c1g']].sum(axis=1)

from plot.distribution import distribution_plot
distribution_plot(df_1.loc[:, 'c1_sum'], xlabel = 'C1 Sum', with_normal_curve = False)

# %%
df_1_describe = df_1['c1_sum'].describe()
mean = df_1_describe['mean']
std = df_1_describe['std']
median = df_1_describe['50%']
_min = df_1_describe['min']
_max = df_1_describe['max']
q1 = df_1_describe['25%']
q3 = df_1_describe['75%']
mode = df_1.loc[:, 'c1_sum'].mode()[0]

# %% [markdown]
# ### Answers

# %%
import pandas as pd

answer = pd.DataFrame({
    'Statistic': ['Mean', 'Median', 'Mode', 'Range', 'Q1', 'Q3', 'Standard Deviation'],
    'Value': [mean, median, mode, _max - _min, q1, q3, std]
})

answer.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0707">
#   <thead>
#     <tr>
#       <th id="T_d0707_level0_col0" class="col_heading level0 col0" >Statistic</th>
#       <th id="T_d0707_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d0707_row0_col0" class="data row0 col0" >Mean</td>
#       <td id="T_d0707_row0_col1" class="data row0 col1" >18.387097</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row1_col0" class="data row1 col0" >Median</td>
#       <td id="T_d0707_row1_col1" class="data row1 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row2_col0" class="data row2 col0" >Mode</td>
#       <td id="T_d0707_row2_col1" class="data row2 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row3_col0" class="data row3 col0" >Range</td>
#       <td id="T_d0707_row3_col1" class="data row3 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row4_col0" class="data row4 col0" >Q1</td>
#       <td id="T_d0707_row4_col1" class="data row4 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row5_col0" class="data row5 col0" >Q3</td>
#       <td id="T_d0707_row5_col1" class="data row5 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d0707_row6_col0" class="data row6 col0" >Standard Deviation</td>
#       <td id="T_d0707_row6_col1" class="data row6 col1" >3.388347</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Q2: 分別計算個人收入（b1）的百分等級和Z分數，並比較原始分數、百分等級、Z分數三者的偏態

# %%
df_2 = df[['b1']].copy().rename(columns = { 'b1': 'income' })

# %% [markdown]
# ### Filter out '拒答'(997.0), '漏答'(998.0), '不適用'(999.0), and nullish rows from dataset

# %%
df_2_clean = df_2[
    (df_2['income'].notna()) & 
    (~df_2['income'].isin([997.0, 998.0, 999.0]))
]
df_2_clean.value_counts().sort_index()
# Out:
# income
# 0.0       139
# 1.0        29
# 2.0        68
# 3.0       137
# 4.0       201
# 5.0        96
# 6.0        74
# 7.0        25
# 8.0        27
# 9.0         8
# 10.0       19
# 11.0       12
# 12.0        1
# 13.0        4
# 15.0       24
# Name: count, dtype: int64

# %% [markdown]
# ### Plot the distribution histogram

# %%
from plot.distribution import distribution_plot
distribution_plot(df_2_clean['income'], xlabel = 'Income')
